# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Load the image
img = plt.imread(r"image.jpg")

rows, cols, _ = img.shape

plt.title("Original Image")
plt.imshow(img)
plt.show()

# Generate a random key
key = list(range(256))
random.shuffle(key)

def encrypt_image(img, key):
    img1 = np.zeros_like(img, dtype=int)
    for i in range(rows):
        for j in range(cols):
            for k in range(3):
                img1[i][j][k] = key[int(img[i][j][k] * 255)]
    return img1

img1 = encrypt_image(img, key)

plt.title("Encrypted Image")
plt.imshow(img1)
plt.show()

def decrypt_image(img, key):
    img1 = np.zeros_like(img, dtype=int)
    for i in range(rows):
        for j in range(cols):
            for k in range(3):
                img1[i][j][k] = key.index(int(img[i][j][k] * 255))
    return img1

img3 = decrypt_image(img1, key)

plt.title("Decrypted Image")
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 26
#      23                 img1[i][j][k] = key[int(img[i][j][k] * 255)]
#      24     return img1
# ---> 26 img1 = encrypt_image(img, key)
#      28 plt.title("Encrypted Image")
#      29 plt.imshow(img1)
#
# Cell In[3], line 23, in encrypt_image(img, key)
#      21     for j in range(cols):
#      22         for k in range(3):
# ---> 23             img1[i][j][k] = key[int(img[i][j][k] * 255)]
#      24 return img1
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Load the image
img = plt.imread(r"image.jpg")

rows, cols, _ = img.shape

plt.title("Original Image")
plt.imshow(img)
plt.show()

# Generate a random key
key = list(range(256))
random.shuffle(key)

def encrypt_image(img, key):
    img1 = np.zeros_like(img, dtype=int)
    for i in range(rows):
        for j in range(cols):
            for k in range(3):
                img1[i][j][k] = key[int(img[i][j][k] * 255)]
    return img1 / 255.0  # Scale back to [0, 1]

img1 = encrypt_image(img, key)

plt.title("Encrypted Image")
plt.imshow(img1)
plt.show()

def decrypt_image(img, key):
    img1 = np.zeros_like(img, dtype=int)
    for i in range(rows):
        for j in range(cols):
            for k in range(3):
                img1[i][j][k] = key.index(int(img[i][j][k] * 255))
    return img1

img3 = decrypt_image(img1 * 255, key) / 255.0  # Scale back to [0, 1]

plt.title("Decrypted Image")
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 26
#      23                 img1[i][j][k] = key[int(img[i][j][k] * 255)]
#      24     return img1 / 255.0  # Scale back to [0, 1]
# ---> 26 img1 = encrypt_image(img, key)
#      28 plt.title("Encrypted Image")
#      29 plt.imshow(img1)
#
# Cell In[5], line 23, in encrypt_image(img, key)
#      21     for j in range(cols):
#      22         for k in range(3):
# ---> 23             img1[i][j][k] = key[int(img[i][j][k] * 255)]
#      24 return img1 / 255.0
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Load the image
img = plt.imread(r"image.jpg")

rows, cols, _ = img.shape

plt.title("Original Image")
plt.imshow(img)
plt.show()

# Generate a key covering the entire range of pixel values
key = list(range(256))

def encrypt_image(img, key):
    img1 = np.zeros_like(img, dtype=int)
    for i in range(rows):
        for j in range(cols):
            for k in range(3):
                img1[i][j][k] = key[int(img[i][j][k] * 255)]
    return img1 / 255.0  # Scale back to [0, 1]

img1 = encrypt_image(img, key)

plt.title("Encrypted Image")
plt.imshow(img1)
plt.show()

def decrypt_image(img, key):
    img1 = np.zeros_like(img, dtype=int)
    for i in range(rows):
        for j in range(cols):
            for k in range(3):
                img1[i][j][k] = key[int(img[i][j][k] * 255)]
    return img1

img3 = decrypt_image(img1 * 255, key) / 255.0  # Scale back to [0, 1]

plt.title("Decrypted Image")
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 25
#      22                 img1[i][j][k] = key[int(img[i][j][k] * 255)]
#      23     return img1 / 255.0  # Scale back to [0, 1]
# ---> 25 img1 = encrypt_image(img, key)
#      27 plt.title("Encrypted Image")
#      28 plt.imshow(img1)
#
# Cell In[7], line 22, in encrypt_image(img, key)
#      20     for j in range(cols):
#      21         for k in range(3):
# ---> 22             img1[i][j][k] = key[int(img[i][j][k] * 255)]
#      23 return img1 / 255.0
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Load the image
img = plt.imread(r"image.jpg")

rows, cols, _ = img.shape

plt.title("Original Image")
plt.imshow(img)
plt.show()

# Generate a key covering the entire range of pixel values
key = list(range(256))

def encrypt_image(img, key):
  """Encrypts an image using a simple substitution cipher."""
  img1 = np.zeros_like(img, dtype=int)
  for i in range(rows):
    for j in range(cols):
      for k in range(3):
        img1[i][j][k] = key[int(img[i][j][k] * 255) % len(key)]  # Use modulo for index wrapping
  return img1 / 255.0  # Scale back to [0, 1]

img1 = encrypt_image(img, key)

plt.title("Encrypted Image")
plt.imshow(img1)
plt.show()

def decrypt_image(img, key):
  """Decrypts an image encrypted using the same key."""
  img1 = np.zeros_like(img, dtype=int)
  for i in range(rows):
    for j in range(cols):
      for k in range(3):
        img1[i][j][k] = key.index(int(img[i][j][k] * 255))  # Find index of pixel value in key
  return img1 / 255.0  # Scale back to [0, 1]

img3 = decrypt_image(img1 * 255, key) / 255.0  # Scale back to [0, 1]

plt.title("Decrypted Image")
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 41
#      38         img1[i][j][k] = key.index(int(img[i][j][k] * 255))  # Find index of pixel value in key
#      39   return img1 / 255.0  # Scale back to [0, 1]
# ---> 41 img3 = decrypt_image(img1 * 255, key) / 255.0  # Scale back to [0, 1]
#      43 plt.title("Decrypted Image")
#      44 plt.imshow(img3)
#
# Cell In[1], line 38, in decrypt_image(img, key)
#      36   for j in range(cols):
#      37     for k in range(3):
# ---> 38       img1[i][j][k] = key.index(int(img[i][j][k] * 255))  # Find index of pixel value in key
#      39 return img1 / 255.0
#
# ValueError: 57630 is not in list
